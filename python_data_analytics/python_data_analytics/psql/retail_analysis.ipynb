# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 62.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
conn_url = 'postgresql://postgres:password@172.17.0.1:5433/postgres'
engine = create_engine(conn_url)

# %%
df = pd.read_sql_query('Select * from retail',engine)

# %%
df
# Out:
#         invoice_no stock_code                          description  quantity  \
# 0           489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1           489434     79323P                   PINK CHERRY LIGHTS        12
# 2           489434     79323W                  WHITE CHERRY LIGHTS        12
# 3           489434      22041         RECORD FRAME 7" SINGLE SIZE         48
# 4           489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...            ...        ...                                  ...       ...
# 1067366     581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367     581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368     581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369     581587      22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370     581587       POST                              POSTAGE         1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   invoice_no    1067371 non-null  object
#  1   stock_code    1067371 non-null  object
#  2   description   1062989 non-null  object
#  3   quantity      1067371 non-null  int64
#  4   invoice_date  1067371 non-null  datetime64[ns]
#  5   unit_price    1067371 non-null  float64
#  6   customer_id   824364 non-null   float64
#  7   country       1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 65.1+ MB

# %%
df.describe()
# Out:
#            quantity                   invoice_date    unit_price  \
# count  1.067371e+06                        1067371  1.067371e+06
# mean   9.938898e+00  2011-01-02 21:13:55.394028800  4.649388e+00
# min   -8.099500e+04            2009-12-01 07:45:00 -5.359436e+04
# 25%    1.000000e+00            2010-07-09 09:46:00  1.250000e+00
# 50%    3.000000e+00            2010-12-07 15:28:00  2.100000e+00
# 75%    1.000000e+01            2011-07-22 10:23:00  4.150000e+00
# max    8.099500e+04            2011-12-09 12:50:00  3.897000e+04
# std    1.727058e+02                            NaN  1.235531e+02
#
#          customer_id
# count  824364.000000
# mean    15324.638504
# min     12346.000000
# 25%     13975.000000
# 50%     15255.000000
# 75%     16797.000000
# max     18287.000000
# std      1697.464450

# %%
df.isnull().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       4382
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     243007
# country              0
# dtype: int64

# %%
pd.read_sql_query('Select * from retail limit 10',engine)
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1     489434     79323P                   PINK CHERRY LIGHTS        12
# 2     489434     79323W                  WHITE CHERRY LIGHTS        12
# 3     489434      22041         RECORD FRAME 7" SINGLE SIZE         48
# 4     489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5     489434      22064           PINK DOUGHNUT TRINKET POT         24
# 6     489434      21871                  SAVE THE PLANET MUG        24
# 7     489434      21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8     489435      22350                            CAT BOWL         12
# 9     489435      22349       DOG BOWL , CHASING BALL DESIGN        12
#
#          invoice_date  unit_price  customer_id         country
# 0 2009-12-01 07:45:00        6.95      13085.0  United Kingdom
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#         invoice_no stock_code                     description  quantity  \
# 263         489464      21733                    85123a mixed       -96
# 283         489463      71477                           short      -240
# 284         489467     85123A                     21733 mixed      -192
# 470         489521      21646                            None       -50
# 577         489525     85226C       BLUE PULL BACK RACING CAR         1
# ...            ...        ...                             ...       ...
# 1066997     581498     85099B         JUMBO BAG RED RETROSPOT         5
# 1066998     581498     85099C  JUMBO  BAG BAROQUE BLACK WHITE         4
# 1066999     581498      85150   LADIES & GENTLEMEN METAL SIGN         1
# 1067000     581498      85174               S/4 CACTI CANDLES         1
# 1067001     581498        DOT                  DOTCOM POSTAGE         1
#
#                invoice_date  unit_price  customer_id         country
# ...

# %%
pd.read_sql_query('Select count(*)as total from retail',engine)
# Out:
#      total
# 0  1067371

# %%
pd.read_sql_query('Select count(distinct customer_id) from retail',engine)
# Out:
#    count
# 0   5942

# %%
pd.read_sql_query('Select min(invoice_date) as start_date , max(invoice_date) as end_date from retail',engine)
# Out:
#            start_date            end_date
# 0 2009-12-01 07:45:00 2011-12-09 12:50:00

# %%
pd.read_sql_query('Select count(distinct stock_code) from retail',engine)
# Out:
#    count
# 0   5305

# %%
df['line_total'] = df['unit_price']*df['quantity']

# %%
invoice_totals = df.groupby('invoice_no')['line_total'].sum()

# %%
avg_invoice = invoice_totals[invoice_totals>0].mean()
print(avg_invoice)
# Out:
# 523.3037611158242

# %%
df['month'] = df['invoice_date'].dt.to_period('M')
monthly_revenue = df.groupby('month').apply(lambda x : (x['unit_price'] * x['quantity']).sum())
monthly_revenue
# Out:
# month
# 2009-12     799847.110
# 2010-01     624032.892
# 2010-02     533091.426
# 2010-03     765848.761
# 2010-04     590580.432
# 2010-05     615322.830
# 2010-06     679786.610
# 2010-07     575236.360
# 2010-08     656776.340
# 2010-09     853650.431
# 2010-10    1045168.350
# 2010-11    1422654.642
# 2010-12    1126445.470
# 2011-01     560000.260
# 2011-02     498062.650
# 2011-03     683267.080
# 2011-04     493207.121
# 2011-05     723333.510
# 2011-06     691123.120
# 2011-07     681300.111
# 2011-08     682680.510
# 2011-09    1019687.622
# 2011-10    1070704.670
# 2011-11    1461756.250
# 2011-12     433686.010
# Freq: M, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
pd.read_sql_query('Select sum(unit_price*quantity) from retail',engine)
# Out:
#             sum
# 0  1.928725e+07

# %%
monthly_revenue.plot(x='month', y='revenue', kind = 'bar', figsize = (10,5))
# Out:
# <Axes: xlabel='month'>
